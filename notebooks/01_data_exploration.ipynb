# %%
import wfdb
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load label file
labels = pd.read_csv('data/raw/cinc2017/REFERENCE-v3.csv', header=None, names=['record', 'label'])
print(labels['label'].value_counts())
# Out:
# label
# N    5076
# O    2415
# A     758
# ~     279
# Name: count, dtype: int64

# %%
# Load and plot one record
record = wfdb.rdrecord('data/raw/cinc2017/training2017/A00023')
plt.plot(record.p_signal[:1000, 0])
plt.title('Example ECG — Normal')
plt.show()
